# %%
from Source_Files.Crawling.Wanted_Crawling import *
from Source_Files.Crawling.Data_Analysis import *

# %%
'''
# Wanted Crawling
원티드 사이트의 메인 홈페이지 공고들으 가져옵니다
해당 공고들의 id값들을 이용해 공고에 접근하고
각 공고의 상세정보를 가져옵니다
'''

posts = get_wanted_main_crawling()
# Out:
# Fetching job posts: 10000post [01:31, 109.04post/s]

# %%
posts
# Out:
# [{'id': 278301,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 23419,
#    'name': '씨제이올리브영(CJ올리브영)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/23419/f7aifr54bs6x1m9n__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/23419/f7aifr54bs6x1m9n__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '용산구'},
#   'position': 'UIUX 디자이너(신사업 프로덕트)',
#   'category_tag': {'parent_id': 511, 'id': 599},
#   'attraction_tags': [10433,
#    10401,
#    10468,
#    10405,
#    10438,
#    10564,
#    10440,
#    10441,
#    10408,
#    10537,
#    10436,
#    10486,
#    10423,
#    10425],
#   'skill_tags': [],
#   'user_oriented_tags': [10251, 10379, 10253],
#   'annual_from': 4,
#   'annual_to': 11,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 278604,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 16782,
#    'name': '테크타카(ARGO)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/16782/e39dw1qlbwc3ijzc__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/16782/e39dw1qlbwc3ijzc__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '서초구'},
#   'position': 'Jr.Backend Engineer (Java / Spring)',
#   'category_tag': {'parent_id': 518, 'id': 872},
#   'attraction_tags': [10403,
#    10468,
#    10437,
#    10438,
#    10439,
#    10408,
#    10436,
#    10420,
#    10485,
#    10423,
#    10521,
#    10426,
#    10427,
#    10398,
#    10431],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10246,
#    10248,
#    10249,
#    10377,
#    10251,
#    10379,
#    10381,
#    10380,
#    10255,
#    10384,
#    10385,
#    10252,
#    10386,
#    10253,
#    10265,
#    10266,
#    10250,
#    10378],
#   'annual_from': 0,
#   'annual_to': 5,
#   'is_newbie': True,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 278837,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 137,
#    'name': '여기어때컴퍼니',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/137/oqkbo69az563n2fs__1080_790.png',
#    'thumb': 'https://static.wanted.co.kr/images/company/137/oqkbo69az563n2fs__400_400.png',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': 'Platform Designer',
#   'category_tag': {'parent_id': 511, 'id': 592},
#   'attraction_tags': [10509,
#    10523,
#    10397,
#    10401,
#    10404,
#    10408,
#    10537,
#    10413,
#    10418,
#    10423,
#    10431,
#    10436,
#    10437,
#    10438,
#    10564,
#    10440,
#    10441,
#    10443,
#    10468,
#    10485,
#    10486],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10247,
#    10248,
#    10377,
#    10250,
#    10378,
#    10249,
#    10253,
#    10251,
#    10383,
#    10384,
#    10385,
#    10379,
#    10252,
#    10386,
#    10265,
#    10266],
#   'annual_from': 3,
#   'annual_to': 7,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 278653,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 1916,
#    'name': '짐싸(ZIMSSA)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/1916/t2z2la6pnlmigmoj__1080_790.png',
#    'thumb': 'https://static.wanted.co.kr/images/company/1916/t2z2la6pnlmigmoj__400_400.png',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': '프로덕트 매니저(신입)',
#   'category_tag': {'parent_id': 507, 'id': 565},
#   'attraction_tags': [10401,
#    10402,
#    10433,
#    10436,
#    10437,
#    10438,
#    10468,
#    10408,
#    10413,
#    10509,
#    10416,
#    10426,
#    10395],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10246,
#    10377,
#    10249,
#    10251,
#    10380,
#    10253,
#    10379,
#    10385,
#    10264,
#    10266],
#   'annual_from': 0,
#   'annual_to': 1,
#   'is_newbie': True,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 280236,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 2331,
#    'name': '케이티밀리의서재',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/2331/x16itycnlsqhg0zo__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/2331/x16itycnlsqhg0zo__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '마포구'},
#   'position': '브랜드 & 콘텐츠 디자이너',
#   'category_tag': {'parent_id': 511, 'id': 592},
#   'attraction_tags': [10433,
#    10401,
#    10403,
#    10468,
#    10408,
#    10537,
#    10447,
#    10420,
#    10485,
#    10486,
#    10523,
#    10398],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10377,
#    10250,
#    10378,
#    10249,
#    10253,
#    10251,
#    10379,
#    10254,
#    10385,
#    10382,
#    10265,
#    10266],
#   'annual_from': 5,
#   'annual_to': 10,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 277111,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 593,
#    'name': '카카오뱅크(kakaobank)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/593/j0s5yyuu3dfypgne__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/593/j0s5yyuu3dfypgne__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '경기', 'district': '성남시'},
#   'position': '프로덕트 디자이너 - 글로벌 서비스',
#   'category_tag': {'parent_id': 511, 'id': 597},
#   'attraction_tags': [10509,
#    10396,
#    10401,
#    10405,
#    10408,
#    10413,
#    10420,
#    10422,
#    10423,
#    10425,
#    10427,
#    10433,
#    10438,
#    10440,
#    10447,
#    10467,
#    10468,
#    10485,
#    10486],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10246,
#    10377,
#    10250,
#    10378,
#    10380,
#    10249,
#    10382,
#    10254,
#    10385,
#    10265,
#    10266],
#   'annual_from': 3,
#   'annual_to': 100,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 48832,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 859,
#    'name': '스테이션3(다방)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/859/hfqtodm1i4uvb29k__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/859/hfqtodm1i4uvb29k__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '서초구'},
#   'position': 'UI/UX 디자이너',
#   'category_tag': {'parent_id': 511, 'id': 595},
#   'attraction_tags': [10403,
#    10436,
#    10437,
#    10467,
#    10468,
#    10440,
#    10409,
#    10413,
#    10509,
#    10485,
#    10486,
#    10423,
#    10399],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10377,
#    10249,
#    10251,
#    10379,
#    10253,
#    10252,
#    10385,
#    10386,
#    10265,
#    10266],
#   'annual_from': 3,
#   'annual_to': 10,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 279166,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 63,
#    'name': '뱅크샐러드',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/63/bclu6isv9svc7esq__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/63/bclu6isv9svc7esq__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '마포구'},
#   'position': '프로덕트 매니저 (Product Manager, PFM)',
#   'category_tag': {'parent_id': 507, 'id': 565},
#   'attraction_tags': [10508,
#    10509,
#    10521,
#    10523,
#    10397,
#    10401,
#    10403,
#    10409,
#    10537,
#    10412,
#    10413,
#    10420,
#    10423,
#    10426,
#    10436,
#    10439,
#    10440,
#    10466,
#    10468,
#    10485],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10246,
#    10247,
#    10248,
#    10377,
#    10249,
#    10250,
#    10380,
#    10253,
#    10378,
#    10251,
#    10384,
#    10385,
#    10379,
#    10254,
#    10382,
#    10252,
#    10386,
#    10383,
#    10265,
#    10266],
#   'annual_from': 0,
#   'annual_to': 100,
#   'is_newbie': True,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 280245,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 2331,
#    'name': '케이티밀리의서재',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/2331/x16itycnlsqhg0zo__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/2331/x16itycnlsqhg0zo__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '마포구'},
#   'position': '프로덕트 디자이너',
#   'category_tag': {'parent_id': 511, 'id': 592},
#   'attraction_tags': [10433,
#    10401,
#    10403,
#    10468,
#    10408,
#    10537,
#    10447,
#    10420,
#    10485,
#    10486,
#    10523,
#    10398],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10377,
#    10250,
#    10378,
#    10249,
#    10253,
#    10251,
#    10379,
#    10254,
#    10385,
#    10382,
#    10265,
#    10266],
#   'annual_from': 5,
#   'annual_to': 10,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 276130,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 23419,
#    'name': '씨제이올리브영(CJ올리브영)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/23419/f7aifr54bs6x1m9n__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/23419/f7aifr54bs6x1m9n__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '용산구'},
#   'position': '브랜딩/그래픽 디자이너',
#   'category_tag': {'parent_id': 511, 'id': 592},
#   'attraction_tags': [10433,
#    10401,
#    10468,
#    10405,
#    10438,
#    10564,
#    10440,
#    10441,
#    10408,
#    10537,
#    10436,
#    10486,
#    10423,
#    10425],
#   'skill_tags': [],
#   'user_oriented_tags': [10251, 10379, 10253],
#   'annual_from': 8,
#   'annual_to': 12,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 279453,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 1970,
#    'name': '스왈라비',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/1970/rdj2jvbz9oksd5md__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/1970/rdj2jvbz9oksd5md__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': '[워크온] UI/UX 디자이너',
#   'category_tag': {'parent_id': 511, 'id': 597},
#   'attraction_tags': [10402, 10436, 10439, 10408, 10395],
#   'skill_tags': [],
#   'user_oriented_tags': [10249, 10253, 10385, 10264, 10266],
#   'annual_from': 0,
#   'annual_to': 1,
#   'is_newbie': True,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 266805,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 53,
#    'name': '쿠팡',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/53/zkuycl59i67pmnhl__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/53/zkuycl59i67pmnhl__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': 'Staff, Front-end Engineer(Fintech Frontend)',
#   'category_tag': {'parent_id': 518, 'id': 669},
#   'attraction_tags': [10399,
#    10401,
#    10406,
#    10409,
#    10537,
#    10412,
#    10413,
#    10420,
#    10423,
#    10426,
#    10433,
#    10436,
#    10437,
#    10564,
#    10439,
#    10440,
#    10443,
#    10447,
#    10468,
#    10485,
#    10486],
#   'skill_tags': [1698, 1541, 1469],
#   'user_oriented_tags': [10245,
#    10246,
#    10248,
#    10377,
#    10249,
#    10251,
#    10379,
#    10253,
#    10380,
#    10252,
#    10254,
#    10385,
#    10386,
#    10382,
#    10384,
#    10266],
#   'annual_from': 7,
#   'annual_to': 100,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 279483,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 25926,
#    'name': '토스페이먼츠',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/25926/owr6ikoope0b8prw__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/25926/owr6ikoope0b8prw__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': 'Frontend Developer',
#   'category_tag': {'parent_id': 518, 'id': 669},
#   'attraction_tags': [10401,
#    10404,
#    10436,
#    10468,
#    10440,
#    10408,
#    10412,
#    10508,
#    10511,
#    10420,
#    10485,
#    10486,
#    10424,
#    10426,
#    10429,
#    10399],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10246,
#    10248,
#    10377,
#    10250,
#    10378,
#    10252,
#    10253,
#    10380,
#    10249,
#    10384,
#    10385,
#    10386,
#    10379,
#    10251,
#    10254,
#    10382,
#    10265,
#    10266],
#   'annual_from': 0,
#   'annual_to': 100,
#   'is_newbie': True,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 279823,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 30659,
#    'name': '선한사람들',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/30659/bgsxe9cra4lalkga__1080_790.png',
#    'thumb': 'https://static.wanted.co.kr/images/company/30659/bgsxe9cra4lalkga__400_400.png',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': '프론트앤드 개발자',
#   'category_tag': {'parent_id': 518, 'id': 669},
#   'attraction_tags': [10433,
#    10402,
#    10401,
#    10468,
#    10467,
#    10437,
#    10407,
#    10436,
#    10444,
#    10413,
#    10509,
#    10416,
#    10423,
#    10426],
#   'skill_tags': [],
#   'user_oriented_tags': [10246,
#    10249,
#    10250,
#    10378,
#    10251,
#    10253,
#    10379,
#    10380,
#    10385,
#    10264,
#    10266],
#   'annual_from': 0,
#   'annual_to': 1,
#   'is_newbie': True,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 271805,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 23419,
#    'name': '씨제이올리브영(CJ올리브영)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/23419/f7aifr54bs6x1m9n__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/23419/f7aifr54bs6x1m9n__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '용산구'},
#   'position': '신사업 프로덕트 PO',
#   'category_tag': {'parent_id': 507, 'id': 565},
#   'attraction_tags': [10433,
#    10401,
#    10468,
#    10405,
#    10438,
#    10564,
#    10440,
#    10441,
#    10408,
#    10537,
#    10436,
#    10486,
#    10423,
#    10425],
#   'skill_tags': [],
#   'user_oriented_tags': [10251, 10379, 10253],
#   'annual_from': 3,
#   'annual_to': 10,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 279842,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 13630,
#    'name': '제이티비씨(JTBC)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/13630/5fuh1jrkkxh6ruzy__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/13630/5fuh1jrkkxh6ruzy__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '마포구'},
#   'position': '브랜드 디자이너',
#   'category_tag': {'parent_id': 511, 'id': 592},
#   'attraction_tags': [10433,
#    10404,
#    10409,
#    10413,
#    10509,
#    10416,
#    10423,
#    10425,
#    10396],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10246,
#    10377,
#    10250,
#    10378,
#    10249,
#    10380,
#    10385,
#    10265,
#    10266],
#   'annual_from': 5,
#   'annual_to': 10,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 280171,
#   'reward_total': '',
#   'is_bookmark': False,
#   'company': {'id': 51074,
#    'name': '국가정보원',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/51074/my5wxvzj3qxlztbu__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/51074/my5wxvzj3qxlztbu__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': None},
#   'position': '과학기술 (전산)',
#   'category_tag': {'parent_id': 518, 'id': 873},
#   'attraction_tags': [10468, 10447],
#   'skill_tags': [],
#   'user_oriented_tags': [10253, 10382, 10254, 10381, 10255],
#   'annual_from': 1,
#   'annual_to': 100,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 0,
#    'reward_recommendee': 0,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '',
#    'formatted_recommender': '',
#    'formatted_recommendee': ''}},
#  {'id': 275991,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 53,
#    'name': '쿠팡',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/53/zkuycl59i67pmnhl__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/53/zkuycl59i67pmnhl__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '송파구'},
#   'position': 'Product Manager (Consumer Growth Product)',
#   'category_tag': {'parent_id': 507, 'id': 564},
#   'attraction_tags': [10508,
#    10509,
#    10399,
#    10401,
#    10406,
#    10409,
#    10537,
#    10412,
#    10413,
#    10420,
#    10423,
#    10426,
#    10433,
#    10436,
#    10437,
#    10564,
#    10439,
#    10440,
#    10443,
#    10447,
#    10468,
#    10485,
#    10486],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10246,
#    10248,
#    10377,
#    10249,
#    10251,
#    10379,
#    10253,
#    10380,
#    10252,
#    10254,
#    10385,
#    10386,
#    10382,
#    10384,
#    10266],
#   'annual_from': 4,
#   'annual_to': 100,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 273518,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 21933,
#    'name': '현대캐피탈',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/21933/lkeo6pdcbgznxuaz__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/21933/lkeo6pdcbgznxuaz__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '중구'},
#   'position': 'UI Designer',
#   'category_tag': {'parent_id': 511, 'id': 603},
#   'attraction_tags': [10433,
#    10467,
#    10468,
#    10405,
#    10409,
#    10420,
#    10485,
#    10422,
#    10486,
#    10425,
#    10396,
#    10430],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10377,
#    10250,
#    10378,
#    10249,
#    10254,
#    10382,
#    10385,
#    10265,
#    10266],
#   'annual_from': 4,
#   'annual_to': 11,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 278029,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 99,
#    'name': '버즈빌(buzzvil)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/99/8hp072pdi8l7xh7o__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/99/8hp072pdi8l7xh7o__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '송파구'},
#   'position': 'Product Designer (2년 이상)',
#   'category_tag': {'parent_id': 511, 'id': 603},
#   'attraction_tags': [10433,
#    10403,
#    10436,
#    10437,
#    10468,
#    10439,
#    10440,
#    10409,
#    10443,
#    10412,
#    10508,
#    10485,
#    10423,
#    10523,
#    10398],
#   'skill_tags': [10172, 3974, 4679],
#   'user_oriented_tags': [10245,
#    10247,
#    10248,
#    10377,
#    10249,
#    10250,
#    10378,
#    10253,
#    10251,
#    10383,
#    10384,
#    10385,
#    10379,
#    10265,
#    10266],
#   'annual_from': 2,
#   'annual_to': 100,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 282132,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 102,
#    'name': '우아한형제들(배달의민족)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/102/lhnzt8yqwqslevr1__1080_790.png',
#    'thumb': 'https://static.wanted.co.kr/images/company/102/lhnzt8yqwqslevr1__400_400.png',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '송파구'},
#   'position': '콘텐츠 에디터',
#   'category_tag': {'parent_id': 523, 'id': 1635},
#   'attraction_tags': [10509,
#    10397,
#    10400,
#    10405,
#    10409,
#    10537,
#    10412,
#    10413,
#    10422,
#    10424,
#    10426,
#    10427,
#    10430,
#    10436,
#    10439,
#    10462,
#    10468,
#    10485,
#    10486],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10247,
#    10248,
#    10377,
#    10250,
#    10378,
#    10249,
#    10253,
#    10251,
#    10383,
#    10384,
#    10385,
#    10379,
#    10254,
#    10382,
#    10265,
#    10266],
#   'annual_from': 0,
#   'annual_to': 100,
#   'is_newbie': True,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 278425,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 5692,
#    'name': '보이저엑스(VoyagerX)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/5692/xbzcmswie97oe4a5__1080_790.png',
#    'thumb': 'https://static.wanted.co.kr/images/company/5692/xbzcmswie97oe4a5__400_400.png',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '서초구'},
#   'position': '[Vrew] 웹 애플리케이션 개발자',
#   'category_tag': {'parent_id': 518, 'id': 873},
#   'attraction_tags': [10400,
#    10403,
#    10436,
#    10408,
#    10537,
#    10412,
#    10508,
#    10447,
#    10485,
#    10399],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10248,
#    10377,
#    10250,
#    10251,
#    10379,
#    10253,
#    10382,
#    10254,
#    10384,
#    10378,
#    10249,
#    10385,
#    10265,
#    10266],
#   'annual_from': 0,
#   'annual_to': 35,
#   'is_newbie': True,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 281191,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 1160,
#    'name': '피알앤디컴퍼니(헤이딜러)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/1160/uxkfrbgti4rrszte__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/1160/uxkfrbgti4rrszte__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '서초구'},
#   'position': 'PM (Product Manager)',
#   'category_tag': {'parent_id': 507, 'id': 559},
#   'attraction_tags': [10433,
#    10401,
#    10403,
#    10436,
#    10437,
#    10438,
#    10468,
#    10440,
#    10408,
#    10418,
#    10485,
#    10486,
#    10423,
#    10399],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10246,
#    10247,
#    10377,
#    10250,
#    10251,
#    10379,
#    10253,
#    10378,
#    10249,
#    10255,
#    10385,
#    10381,
#    10383,
#    10380,
#    10265,
#    10266],
#   'annual_from': 2,
#   'annual_to': 100,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 278634,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 4527,
#    'name': '포스타입',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/4527/ophsxyxqezqbfbv4__1080_790.png',
#    'thumb': 'https://static.wanted.co.kr/images/company/4527/ophsxyxqezqbfbv4__400_400.png',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': '프로덕트 매니저',
#   'category_tag': {'parent_id': 507, 'id': 564},
#   'attraction_tags': [10433,
#    10402,
#    10401,
#    10436,
#    10437,
#    10408,
#    10413,
#    10509,
#    10485,
#    10423,
#    10492,
#    10399],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10247,
#    10377,
#    10249,
#    10251,
#    10379,
#    10253,
#    10383,
#    10385,
#    10264,
#    10266],
#   'annual_from': 2,
#   'annual_to': 7,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 278651,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 4527,
#    'name': '포스타입',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/4527/ophsxyxqezqbfbv4__1080_790.png',
#    'thumb': 'https://static.wanted.co.kr/images/company/4527/ophsxyxqezqbfbv4__400_400.png',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': 'CX 매니저(PM 조직 소속)',
#   'category_tag': {'parent_id': 507, 'id': 564},
#   'attraction_tags': [10433,
#    10402,
#    10401,
#    10436,
#    10437,
#    10408,
#    10413,
#    10509,
#    10485,
#    10423,
#    10492,
#    10399],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10247,
#    10377,
#    10249,
#    10251,
#    10379,
#    10253,
#    10383,
#    10385,
#    10264,
#    10266],
#   'annual_from': 0,
#   'annual_to': 7,
#   'is_newbie': True,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 279405,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 63,
#    'name': '뱅크샐러드',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/63/bclu6isv9svc7esq__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/63/bclu6isv9svc7esq__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '마포구'},
#   'position': '프로덕트 매니저 (Product Manager, 카드 PA)',
#   'category_tag': {'parent_id': 507, 'id': 565},
#   'attraction_tags': [10508,
#    10509,
#    10521,
#    10523,
#    10397,
#    10401,
#    10403,
#    10409,
#    10537,
#    10412,
#    10413,
#    10420,
#    10423,
#    10426,
#    10436,
#    10439,
#    10440,
#    10466,
#    10468,
#    10485],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10246,
#    10247,
#    10248,
#    10377,
#    10249,
#    10250,
#    10380,
#    10253,
#    10378,
#    10251,
#    10384,
#    10385,
#    10379,
#    10254,
#    10382,
#    10252,
#    10386,
#    10383,
#    10265,
#    10266],
#   'annual_from': 0,
#   'annual_to': 100,
#   'is_newbie': True,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 262948,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 2331,
#    'name': '케이티밀리의서재',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/2331/x16itycnlsqhg0zo__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/2331/x16itycnlsqhg0zo__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '마포구'},
#   'position': '서비스 기획 매니저',
#   'category_tag': {'parent_id': 507, 'id': 565},
#   'attraction_tags': [10433,
#    10401,
#    10403,
#    10468,
#    10408,
#    10537,
#    10447,
#    10420,
#    10485,
#    10486,
#    10523,
#    10398],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10377,
#    10250,
#    10378,
#    10249,
#    10253,
#    10251,
#    10379,
#    10254,
#    10385,
#    10382,
#    10265,
#    10266],
#   'annual_from': 5,
#   'annual_to': 12,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 278623,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 4522,
#    'name': '마이노멀컴퍼니',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/4522/iye89spykv1pqi8m__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/4522/iye89spykv1pqi8m__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': '[마이노멀] BX / 그래픽 디자이너',
#   'category_tag': {'parent_id': 511, 'id': 592},
#   'attraction_tags': [10433,
#    10402,
#    10401,
#    10436,
#    10437,
#    10468,
#    10439,
#    10408,
#    10416,
#    10423,
#    10395],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10246,
#    10377,
#    10250,
#    10378,
#    10249,
#    10253,
#    10251,
#    10379,
#    10380,
#    10385,
#    10264,
#    10266],
#   'annual_from': 3,
#   'annual_to': 7,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 278185,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 859,
#    'name': '스테이션3(다방)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/859/hfqtodm1i4uvb29k__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/859/hfqtodm1i4uvb29k__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '서초구'},
#   'position': '서비스기획 및 PM',
#   'category_tag': {'parent_id': 507, 'id': 564},
#   'attraction_tags': [10403,
#    10436,
#    10437,
#    10467,
#    10468,
#    10440,
#    10409,
#    10413,
#    10509,
#    10485,
#    10486,
#    10423,
#    10399],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10377,
#    10249,
#    10251,
#    10379,
#    10253,
#    10252,
#    10385,
#    10386,
#    10265,
#    10266],
#   'annual_from': 3,
#   'annual_to': 10,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 275967,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 47417,
#    'name': '토스플레이스',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/47417/kzalrowgz0wizwwi__1080_790.png',
#    'thumb': 'https://static.wanted.co.kr/images/company/47417/kzalrowgz0wizwwi__400_400.png',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': 'Frontend UX Engineer (Design System)',
#   'category_tag': {'parent_id': 518, 'id': 873},
#   'attraction_tags': [10401,
#    10403,
#    10436,
#    10468,
#    10407,
#    10440,
#    10412,
#    10508,
#    10511,
#    10429,
#    10424,
#    10426,
#    10397],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10248,
#    10377,
#    10250,
#    10378,
#    10252,
#    10253,
#    10249,
#    10251,
#    10384,
#    10385,
#    10386,
#    10379,
#    10254,
#    10382,
#    10265],
#   'annual_from': 1,
#   'annual_to': 15,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 278524,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 36417,
#    'name': '비상교육',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/36417/vmy3aekodvvjqpc4__1080_790.png',
#    'thumb': 'https://static.wanted.co.kr/images/company/36417/vmy3aekodvvjqpc4__400_400.png',
#    'video': None},
#   'address': {'country': '한국', 'location': '경기', 'district': '과천시'},
#   'position': 'AI 디지털교과서 서비스 기획',
#   'category_tag': {'parent_id': 507, 'id': 10115},
#   'attraction_tags': [10509,
#    10399,
#    10400,
#    10405,
#    10409,
#    10412,
#    10413,
#    10416,
#    10422,
#    10423,
#    10430,
#    10436,
#    10437,
#    10439,
#    10443,
#    10467,
#    10468,
#    10485,
#    10486],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10246,
#    10377,
#    10249,
#    10379,
#    10380,
#    10253,
#    10385,
#    10265,
#    10266],
#   'annual_from': 0,
#   'annual_to': 1,
#   'is_newbie': True,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 276991,
#   'reward_total': '',
#   'is_bookmark': False,
#   'company': {'id': 1939,
#    'name': '코드잇(codeit)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/1939/swzwjygoxj6izlei__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/1939/swzwjygoxj6izlei__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '중구'},
#   'position': '[인턴] 프로덕트 디자이너',
#   'category_tag': {'parent_id': 511, 'id': 597},
#   'attraction_tags': [10522,
#    10523,
#    10395,
#    10401,
#    10403,
#    10408,
#    10412,
#    10413,
#    10423,
#    10433,
#    10436,
#    10437,
#    10439,
#    10445,
#    10447,
#    10468,
#    10485,
#    10486,
#    10492],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10246,
#    10248,
#    10377,
#    10250,
#    10379,
#    10380,
#    10253,
#    10252,
#    10254,
#    10384,
#    10382,
#    10386,
#    10378,
#    10385,
#    10255,
#    10381,
#    10265,
#    10266,
#    10249,
#    10251],
#   'annual_from': 0,
#   'annual_to': 1,
#   'is_newbie': True,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 0,
#    'reward_recommendee': 0,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '',
#    'formatted_recommender': '',
#    'formatted_recommendee': ''}},
#  {'id': 280404,
#   'reward_total': '',
#   'is_bookmark': False,
#   'company': {'id': 27439,
#    'name': '마야크루',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/27439/y82yofxofpfb0pn7__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/27439/y82yofxofpfb0pn7__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '마포구'},
#   'position': '[인턴] 프론트엔드/백엔드 개발자',
#   'category_tag': {'parent_id': 518, 'id': 873},
#   'attraction_tags': [10401,
#    10402,
#    10436,
#    10468,
#    10408,
#    10522,
#    10413,
#    10509,
#    10426,
#    10462],
#   'skill_tags': [],
#   'user_oriented_tags': [10247,
#    10249,
#    10250,
#    10251,
#    10252,
#    10253,
#    10379,
#    10378,
#    10383,
#    10385,
#    10386,
#    10264,
#    10266],
#   'annual_from': 0,
#   'annual_to': 1,
#   'is_newbie': True,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 0,
#    'reward_recommendee': 0,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '',
#    'formatted_recommender': '',
#    'formatted_recommendee': ''}},
#  {'id': 279411,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 16782,
#    'name': '테크타카(ARGO)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/16782/e39dw1qlbwc3ijzc__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/16782/e39dw1qlbwc3ijzc__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '서초구'},
#   'position': 'Jr. UI/UX Designer',
#   'category_tag': {'parent_id': 511, 'id': 597},
#   'attraction_tags': [10403,
#    10468,
#    10437,
#    10438,
#    10439,
#    10408,
#    10436,
#    10420,
#    10485,
#    10423,
#    10521,
#    10426,
#    10427,
#    10398,
#    10431],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10246,
#    10248,
#    10249,
#    10377,
#    10251,
#    10379,
#    10381,
#    10380,
#    10255,
#    10384,
#    10385,
#    10252,
#    10386,
#    10253,
#    10265,
#    10266,
#    10250,
#    10378],
#   'annual_from': 1,
#   'annual_to': 3,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 280882,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 6817,
#    'name': '같다(gatda Corp)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/6817/rt5yrues779gthe4__1080_790.png',
#    'thumb': 'https://static.wanted.co.kr/images/company/6817/rt5yrues779gthe4__400_400.png',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '성동구'},
#   'position': '[빼기] Product Designer(+2Y)',
#   'category_tag': {'parent_id': 511, 'id': 879},
#   'attraction_tags': [10402, 10436, 10468, 10408, 10441, 10423, 10395, 10431],
#   'skill_tags': [3808, 1414, 10221, 3032, 10172],
#   'user_oriented_tags': [10245,
#    10377,
#    10250,
#    10251,
#    10252,
#    10253,
#    10379,
#    10254,
#    10382,
#    10378,
#    10386,
#    10249,
#    10385,
#    10264,
#    10266],
#   'annual_from': 2,
#   'annual_to': 10,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 271186,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 137,
#    'name': '여기어때컴퍼니',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/137/oqkbo69az563n2fs__1080_790.png',
#    'thumb': 'https://static.wanted.co.kr/images/company/137/oqkbo69az563n2fs__400_400.png',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': 'Promotion Marketer',
#   'category_tag': {'parent_id': 523, 'id': 710},
#   'attraction_tags': [10509,
#    10523,
#    10397,
#    10401,
#    10404,
#    10408,
#    10537,
#    10413,
#    10418,
#    10423,
#    10431,
#    10436,
#    10437,
#    10438,
#    10564,
#    10440,
#    10441,
#    10443,
#    10468,
#    10485,
#    10486],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10247,
#    10248,
#    10377,
#    10250,
#    10378,
#    10249,
#    10253,
#    10251,
#    10383,
#    10384,
#    10385,
#    10379,
#    10252,
#    10386,
#    10265,
#    10266],
#   'annual_from': 3,
#   'annual_to': 7,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 194059,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 1014,
#    'name': '엘리스',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/1014/qfzxagxlqjbc2qsb__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/1014/qfzxagxlqjbc2qsb__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': '프로덕트 디자이너',
#   'category_tag': {'parent_id': 511, 'id': 599},
#   'attraction_tags': [10400,
#    10433,
#    10403,
#    10436,
#    10437,
#    10468,
#    10564,
#    10408,
#    10537,
#    10445,
#    10446,
#    10447,
#    10523,
#    10485,
#    10486,
#    10423,
#    10426,
#    10395],
#   'skill_tags': [2043, 10172, 3974, 10219],
#   'user_oriented_tags': [10246,
#    10251,
#    10252,
#    10253,
#    10379,
#    10380,
#    10254,
#    10382,
#    10386,
#    10255,
#    10381],
#   'annual_from': 0,
#   'annual_to': 5,
#   'is_newbie': True,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 281926,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 34008,
#    'name': '팀울트라',
# ...
#   'is_bookmark': False,
#   'company': {'id': 49,
#    'name': '데이원컴퍼니',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/49/wghgmlmdm2ophquz__1080_790.png',
#    'thumb': 'https://static.wanted.co.kr/images/company/49/wghgmlmdm2ophquz__400_400.png',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': '[데이원 B2G/제로베이스] 마케팅 디자이너',
#   'category_tag': {'parent_id': 511, 'id': 592},
#   'attraction_tags': [10509,
#    10523,
#    10399,
#    10401,
#    10404,
#    10408,
#    10537,
#    10412,
#    10413,
#    10416,
#    10423,
#    10433,
#    10436,
#    10439,
#    10440,
#    10443,
#    10447,
#    10462,
#    10468,
#    10485],
#   'skill_tags': [],
#   'user_oriented_tags': [10246,
#    10247,
#    10248,
#    10249,
#    10250,
#    10378,
#    10380,
#    10251,
#    10379,
#    10254,
#    10382,
#    10385,
#    10384,
#    10253,
#    10383,
#    10265,
#    10266],
#   'annual_from': 3,
#   'annual_to': 5,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 279503,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 13514,
#    'name': '고위드',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/13514/oenxb07bzmdxarku__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/13514/oenxb07bzmdxarku__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': 'Full-Stack Engineer (풀스택 개발자)',
#   'category_tag': {'parent_id': 518, 'id': 669},
#   'attraction_tags': [10433,
#    10402,
#    10436,
#    10437,
#    10468,
#    10439,
#    10408,
#    10416,
#    10485,
#    10423,
#    10426,
#    10399],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10377,
#    10249,
#    10251,
#    10379,
#    10253,
#    10382,
#    10254,
#    10385,
#    10264,
#    10266],
#   'annual_from': 1,
#   'annual_to': 3,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 279070,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 48249,
#    'name': '매쉬업벤처스',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/48249/vzgxieqcu3pa36md__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/48249/vzgxieqcu3pa36md__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': '투자 심사역 (1년~5년)',
#   'category_tag': {'parent_id': 508, 'id': 10056},
#   'attraction_tags': [10433, 10402, 10401, 10437, 10408, 10423, 10426],
#   'skill_tags': [],
#   'user_oriented_tags': [10386, 10251, 10252, 10379],
#   'annual_from': 0,
#   'annual_to': 1,
#   'is_newbie': True,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 279064,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 23220,
#    'name': '매일유업',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/23220/gry3yhot5ittsnyn__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/23220/gry3yhot5ittsnyn__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '종로구'},
#   'position': '글로벌 B2B 마케팅 (대리급)',
#   'category_tag': {'parent_id': 523, 'id': 950},
#   'attraction_tags': [10433,
#    10436,
#    10437,
#    10438,
#    10405,
#    10408,
#    10412,
#    10413,
#    10508,
#    10509,
#    10423,
#    10427,
#    10396],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10248,
#    10249,
#    10377,
#    10253,
#    10384,
#    10385,
#    10265,
#    10266],
#   'annual_from': 4,
#   'annual_to': 4,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 277682,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 53,
#    'name': '쿠팡',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/53/zkuycl59i67pmnhl__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/53/zkuycl59i67pmnhl__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '송파구'},
#   'position': '마켓플레이스 영업 Account Management (3년 이상)',
#   'category_tag': {'parent_id': 530, 'id': 768},
#   'attraction_tags': [10508,
#    10399,
#    10401,
#    10406,
#    10409,
#    10537,
#    10412,
#    10413,
#    10420,
#    10423,
#    10426,
#    10433,
#    10436,
#    10437,
#    10564,
#    10439,
#    10440,
#    10443,
#    10447,
#    10468,
#    10485,
#    10486],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10246,
#    10248,
#    10377,
#    10249,
#    10251,
#    10379,
#    10253,
#    10380,
#    10252,
#    10254,
#    10385,
#    10386,
#    10382,
#    10384,
#    10266],
#   'annual_from': 3,
#   'annual_to': 7,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 265053,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 12687,
#    'name': '에이치티비욘드',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/12687/hch3l15yz41dpldp__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/12687/hch3l15yz41dpldp__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '송파구'},
#   'position': 'Backend Engineer',
#   'category_tag': {'parent_id': 518, 'id': 872},
#   'attraction_tags': [10403, 10436, 10468, 10440, 10408, 10443, 10398],
#   'skill_tags': [1698, 3078, 1544, 2217, 3451],
#   'user_oriented_tags': [10245,
#    10377,
#    10249,
#    10379,
#    10253,
#    10382,
#    10254,
#    10385,
#    10264,
#    10265,
#    10266],
#   'annual_from': 4,
#   'annual_to': 100,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 278294,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 1488,
#    'name': '톤28',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/1488/pazqutvogb1uso26__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/1488/pazqutvogb1uso26__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '경기', 'district': '성남시'},
#   'position': 'BX디자이너',
#   'category_tag': {'parent_id': 511, 'id': 10130},
#   'attraction_tags': [10401,
#    10402,
#    10436,
#    10437,
#    10564,
#    10408,
#    10413,
#    10509,
#    10416,
#    10420,
#    10518,
#    10426,
#    10395],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10246,
#    10249,
#    10377,
#    10251,
#    10379,
#    10253,
#    10380,
#    10252,
#    10385,
#    10386,
#    10264,
#    10265,
#    10266],
#   'annual_from': 3,
#   'annual_to': 100,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 242470,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 47104,
#    'name': '두어스',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/47104/ojfq2rv5clcfyvtu__1080_790.png',
#    'thumb': 'https://static.wanted.co.kr/images/company/47104/ojfq2rv5clcfyvtu__400_400.png',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': '백엔드 엔지니어',
#   'category_tag': {'parent_id': 518, 'id': 872},
#   'attraction_tags': [10401,
#    10402,
#    10433,
#    10436,
#    10437,
#    10439,
#    10485,
#    10423,
#    10398,
#    10431],
#   'skill_tags': [2976, 1698, 1444, 1554, 2683, 10268],
#   'user_oriented_tags': [10246, 10251, 10380, 10252, 10379, 10253, 10386],
#   'annual_from': 1,
#   'annual_to': 10,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 160736,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 33057,
#    'name': '왓타임',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/33057/ccrxteuwlooss4pv__1080_790.png',
#    'thumb': 'https://static.wanted.co.kr/images/company/33057/ccrxteuwlooss4pv__400_400.png',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': 'B2B 콘텐츠&CRM 마케터',
#   'category_tag': {'parent_id': 523, 'id': 1635},
#   'attraction_tags': [10401, 10402, 10468, 10407, 10431],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10249,
#    10377,
#    10251,
#    10252,
#    10379,
#    10253,
#    10385,
#    10386,
#    10264],
#   'annual_from': 1,
#   'annual_to': 5,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 276291,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 14933,
#    'name': '에이치비엠피',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/14933/czgsysbk3jsb87gg__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/14933/czgsysbk3jsb87gg__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '제주', 'district': '제주시'},
#   'position': '앱 및 웹 서비스 기획 PM (신입~3년미만, 제주근무)',
#   'category_tag': {'parent_id': 507, 'id': 565},
#   'attraction_tags': [10402, 10436, 10437, 10439, 10409],
#   'skill_tags': [10172, 10221, 1414],
#   'user_oriented_tags': [10249, 10253, 10385, 10264, 10266],
#   'annual_from': 0,
#   'annual_to': 2,
#   'is_newbie': True,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 275260,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 52550,
#    'name': '해브해드',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/52550/vwyfqkxih03ilsxp__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/52550/vwyfqkxih03ilsxp__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '마포구'},
#   'position': '패션 브랜드 마케터',
#   'category_tag': {'parent_id': 523, 'id': 1635},
#   'attraction_tags': [10436, 10437, 10509, 10413, 10423],
#   'skill_tags': [],
#   'user_oriented_tags': [10246, 10249, 10380, 10253, 10385, 10264, 10266],
#   'annual_from': 2,
#   'annual_to': 100,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 274949,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 53,
#    'name': '쿠팡',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/53/zkuycl59i67pmnhl__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/53/zkuycl59i67pmnhl__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': '[쿠팡] Staff Product Designer (Design System)',
#   'category_tag': {'parent_id': 511, 'id': 592},
#   'attraction_tags': [10399,
#    10401,
#    10406,
#    10409,
#    10537,
#    10412,
#    10413,
#    10420,
#    10423,
#    10426,
#    10433,
#    10436,
#    10437,
#    10564,
#    10439,
#    10440,
#    10443,
#    10447,
#    10468,
#    10485,
#    10486],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10246,
#    10248,
#    10377,
#    10249,
#    10251,
#    10379,
#    10253,
#    10380,
#    10252,
#    10254,
#    10385,
#    10386,
#    10382,
#    10384,
#    10266],
#   'annual_from': 7,
#   'annual_to': 20,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  {'id': 273550,
#   'reward_total': '100만원',
#   'is_bookmark': False,
#   'company': {'id': 43967,
#    'name': '볼라(와이스)',
#    'application_response_stats': {'avg_rate': 0.0, 'level': 'very_low'}},
#   'title_img': {'origin': 'https://static.wanted.co.kr/images/company/43967/uzlfrn5a1aexwdm4__1080_790.jpg',
#    'thumb': 'https://static.wanted.co.kr/images/company/43967/uzlfrn5a1aexwdm4__400_400.jpg',
#    'video': None},
#   'address': {'country': '한국', 'location': '서울', 'district': '강남구'},
#   'position': '프로덕트 디자이너',
#   'category_tag': {'parent_id': 511, 'id': 594},
#   'attraction_tags': [10401, 10402, 10436, 10408, 10413, 10509],
#   'skill_tags': [],
#   'user_oriented_tags': [10245,
#    10249,
#    10377,
#    10251,
#    10379,
#    10253,
#    10385,
#    10264,
#    10266],
#   'annual_from': 1,
#   'annual_to': 5,
#   'is_newbie': False,
#   'reward': {'id': None,
#    'wd_id': None,
#    'country': 'kr',
#    'user_country': 'KR',
#    'reward_recommender': 500000,
#    'reward_recommendee': 500000,
#    'reward_recommender_unit': 'KRW',
#    'reward_recommendee_unit': 'KRW',
#    'formatted_total': '100만원',
#    'formatted_recommender': '50만원',
#    'formatted_recommendee': '50만원'}},
#  ...]

# %%
ids = get_ids(posts)
ids
# Out:
# [278301,
#  278604,
#  278837,
#  278653,
#  280236,
#  277111,
#  48832,
#  279166,
#  280245,
#  276130,
#  279453,
#  266805,
#  279483,
#  279823,
#  271805,
#  279842,
#  280171,
#  275991,
#  273518,
#  278029,
#  282132,
#  278425,
#  281191,
#  278634,
#  278651,
#  279405,
#  262948,
#  278623,
#  278185,
#  275967,
#  278524,
#  276991,
#  280404,
#  279411,
#  280882,
#  271186,
#  194059,
#  281926,
#  281477,
#  277505,
#  249296,
#  278626,
#  275952,
#  279162,
#  273278,
#  263909,
#  279515,
#  275527,
#  282809,
#  271204,
#  274200,
#  277725,
#  278348,
#  279400,
#  281356,
#  280227,
#  278613,
#  274123,
#  278664,
#  273728,
#  277309,
#  278022,
#  277582,
#  259152,
#  271899,
#  227561,
#  260703,
#  276235,
#  276982,
#  279805,
#  271346,
#  279062,
#  235950,
#  275530,
#  254015,
#  171712,
#  280312,
#  280688,
#  263714,
#  282205,
#  278793,
#  281396,
#  256259,
#  260465,
#  272997,
#  279891,
#  276525,
#  273392,
#  279458,
#  271143,
#  262322,
#  278677,
#  279303,
#  280486,
#  274822,
#  281333,
#  280308,
#  202672,
#  251744,
#  279226,
#  168297,
#  259053,
#  278795,
#  257302,
#  276796,
#  279876,
#  282279,
#  278290,
#  278452,
#  189899,
#  280881,
#  272871,
#  259396,
#  268174,
#  278408,
#  274136,
#  273233,
#  280284,
#  279795,
#  279808,
#  267690,
#  277836,
#  280199,
#  276597,
#  276764,
#  280517,
#  277578,
#  269883,
#  227480,
#  280940,
#  102917,
#  278954,
#  260018,
#  278082,
#  276263,
#  260415,
#  251619,
#  242469,
#  278271,
#  279975,
#  276801,
#  274184,
#  271057,
#  261137,
#  275348,
#  268127,
#  280058,
#  276168,
#  254014,
#  279145,
#  277031,
#  82139,
#  178777,
#  275887,
#  280571,
#  279055,
#  277898,
#  266534,
#  280135,
#  280133,
#  256339,
#  272767,
#  263448,
#  279074,
#  247264,
#  278684,
#  278484,
#  216755,
#  276465,
#  235541,
#  272837,
#  274961,
#  272137,
#  271517,
#  227540,
#  267793,
#  264481,
#  264624,
#  245979,
#  205931,
#  240672,
#  131644,
#  40583,
#  257130,
#  282655,
#  263476,
#  282770,
#  225771,
#  261136,
#  282573,
#  282527,
#  278513,
#  281783,
#  278403,
#  280634,
#  253089,
#  162406,
#  212202,
#  281407,
#  280479,
#  281326,
#  261318,
#  281185,
#  279816,
#  280595,
#  280453,
#  251670,
#  273217,
#  269488,
#  280252,
#  279465,
#  89701,
#  279503,
#  279070,
#  279064,
#  277682,
#  265053,
#  278294,
#  242470,
#  160736,
#  276291,
#  275260,
#  274949,
#  273550,
#  ...]

# %%
with open('../../Data_Files/wanted_main.txt', 'w', encoding='utf-8') as f:
    json.dump(posts,f, ensure_ascii=False, indent=4)

# %%
with open('../../Data_Files/wanted_main.txt', 'r', encoding='utf-8') as f:
    posts = json.load(f)

# %%
post_detail = get_wanted_detail_crawling(ids)
# Out:
# Fetching Detail Contents:  16%|█▌        | 1572/10000 [06:40<30:51,  4.55post/s]  WARNING:root:jid=278965 status 503 → retry in 1.4s
# Fetching Detail Contents:  42%|████▏     | 4166/10000 [17:36<21:06,  4.60post/s]   WARNING:root:jid=279930 HTTPSConnectionPool(host='www.wanted.co.kr', port=443): Read timed out. (read timeout=10) → retry in 1.8s
# Fetching Detail Contents: 100%|██████████| 10000/10000 [51:23<00:00,  3.24post/s]

# %%
post_detail
# Out:
#                                  position  \
# 0                     UIUX 디자이너(신사업 프로덕트)
# 1     Jr.Backend Engineer (Java / Spring)
# 2                       Platform Designer
# 3                            프로덕트 매니저(신입)
# 4                          브랜드 & 콘텐츠 디자이너
# ...                                   ...
# 9995  법인영업(스마트 회의실/강의실 구축관련 IT솔루션 및 제품영업)
# 9996           [트리플콤마] 일본사업총괄(지점장)_근무지 일본
# 9997                              펫보험 전문가
# 9998              보험 전문 유튜브 크리에이터(보험 설계사)
# 9999                      수처리 기계 기계제도 기능사
#
#                                                   intro  \
# 0     All Live Better,\n\nNo.1 헬스&뷰티 스토어 올리브영은 20년 이...
# 1     * To Keep the World in Motion *\n\n테크타카는 아마존과 ...
# 2     | 여기어때 ​'Platform ​Designer'를 ​소개해요\n• Platfor...
# 3     * 자세한 내용은 짐싸 홈페이지를 참고해 주세요! \n\n"누구에게나 쉽고 합리적인...
# 4     독서와 무제한 친해지리, 당신의 일상을 1밀리+\n케이티 밀리의서재(이하 '밀리의서...
# ...                                                 ...
# 9995  오진상사는 1988년 설립되어 현재까지 수많은 국내외 브랜드를 성공적으로 시장에 안...
# 9996  • 트리플콤마는 국내 최초 서류인증 기반 프리미엄 매칭 서비스인 ‘골드스푼’ 을 개...
# 9997  국내 유전자 점유율 1위 마크로젠, 국내 최다 21종 펫 유전자 검사 독점 계약!\...
# 9998  미래 보험시장을 대비할 수 있는 온라인 보험 영업, 보험 유튜브 영업을 100% 지...
# 9999  이엔이텍은 1992년에 설립된 회사로 자본금 3억원 매출액 50억 규모의 중소기업입...
#
#                                              main_tasks  \
# 0     • 올리브영 신사업 디플롯 프로덕트 웹/APP 디자인\n• UI디자인, UX설계 및...
# 1     ∙ 시스템 Architecture Design \n∙ 유연하고 확장성 있는 시스템 ...
# 2     • 여기어때 디자인 시스템을 아우르는 철학과 원칙 수립\n• B2C 및 B2B 플랫...
# 3     • 전사의 목표 및 OKR을 기반으로 필요 업무를 정의하고 프로덕트 고도화\n• 비...
# 4     이 포지션은 독서당 UX설계팀 소속이에요!\n열정적이고 주도적인 디자이너들이 모인 ...
# ...                                                 ...
# 9995  • 스마트 회의실 / 강의실 구축 관련 IT 솔루션 및 관련 제품 영업\n• 영상 ...
# 9996  • 골드스푼 IP를 활용한 일본 시장 진출 전략 수립 및 실행\n• 골드스푼 재팬 ...
# 9997   21종 펫 유전자 검사를 통한 펫보험 영업\n실시간 펫보험 디비를 통한 펫보험 디비영업
# 9998  • 보험 관련 유튜브 영상 출연\n• 댓글 또는 1:1 문의 상담 및 직접 보험 디...
# 9999  제품의 구조 설계 담당합니다.\n기계 부품의 제작 지원합니다.\n설비의 유지보수를 ...
#
#                                            requirements  \
# 0     * 포트폴리오 필수 제출 바랍니다.\n• 포트폴리오 파일 혹은 포트폴리오 사이트 U...
# 1     ∙ Java & Spring 기반 웹서비스 개발 경험\n∙ Spring Framew...
# 2     • 포트폴리오 제출 필수 (PDF 파일 혹은 링크 첨부 가능, Zip 파일 불가)\...
# 3     • 경력: 신입 \n• 업무 우선순위 및 일정 관리가 가능하신 분\n• 디자인, 개...
# 4     • 5-7년 이상 이벤트, 배너, 캠페인 사이트 등 콘텐츠의 모든 과정을 경험한 분...
# ...                                                 ...
# 9995           • 경력 : 경력 2년 ~ 10년\n• 근무형태:정규직(수습기간)-3개월
# 9996  • 모바일 앱 비즈니스 2년 이상 경력 + 일본 현지 근무 3년 이상\n• 일본 도...
# 9997  • 펫보험 영업 경력 또는 관심이 있는 사람\n• 펫 유전자 검사에 관심이 있는 사...
# 9998  • 보험 관련 콘텐츠 제작 경험 또는 흥미가 있는 사람\n• SNS 및 유튜브 채널...
# 9999                   해당 직무 2년 이상 경력자, (필수)전산응용기계제도기능사
#
#                                        preferred_points  \
# 0     [Skill/Experience]\n• 이커머스 플랫폼 프로젝트 경험\n• Agil...
# 1     ∙ 코틀린 사용 및 개발 경험\n∙ 코드 리뷰 및 페어 프로그래밍에 대한 경험\n∙...
# 2     • OTA 서비스와 여행 커머스 업계에 대한 이해가 높은 분\n• 디자인 시스템을 ...
# 3     • OKR 기반 조직에서의 제품 개발 경험이 있으신 분\n• O2O 서비스 관련 업...
# 4     • 구독서비스에 관심이 많으시면 좋아요.\n• 업무에 임하는 진지한 자세와 리더십이...
# ...                                                 ...
# 9995  • 화상회의장비 및 관련 SW 경력자\n• 영상 / 음향 장비 영업 및 설치 경력자...
# 9996  • 일본 대학 졸업자, 일본 회사 근무 경험자\n• 주도적으로 업무를 찾아서 하며,...
# 9997                            • 보험영업 경력자\n• 펫보험영업 경력자
# 9998                              - 보험영업 경력자\n- 유튜버 경력자
# 9999                                           해당직무 경험자
#
#                                                benefits  \
# 0     • CJ그룹 계열사 인프라 40% 할인\n• 카페테리아 포인트(현금성 복지 포인트)...
# 1     테크타카는 자율적인 문화를 바탕으로 팀원 여러분들의 능력을 마음껏 펼칠 수 있도록 ...
# 2     1. WORK&LIFE\n• 월요일 1시 출근 : 여유있는 한 주의 시작\n• 자율...
# 3     | 짐싸의 업무환경 \n• 오전 8~10시 자율적으로 출근, 17~19시 퇴근 유연...
# 4     [밀리다움]\n임팩트를 만드는 도전에 집중합니다. \n• 밀리는 도전을 추구합니다....
# ...                                                 ...
# 9995  • 각종 경조사 지원\n• 구내식당(사원식당)\n• 퇴직연금, 인센티브제, 퇴직금,...
# 9996  • 연봉은 협의에 따라 결정됩니다.\n• 성과에 따라 인센티브/스톡옵션 등 기회가 ...
# 9997  • 실시간 유튜브 디비 제공\n• 실시간 펫보험 디비 제공\n• 펫보험 디비영업 교...
# 9998  • 실시간 유튜브 디비 제공\n• 보험 마케팅 전문 교육 지원\n• 유튜브 디비영업...
# 9999                               4대보험, 명절,휴가 상여금, 기숙사
#
#                                             hire_rounds  \
# 0     ※ 전형 안내\n\n서류전형 - 1차면접 - 온라인 인성검사 - 2차면접 - Ref...
# 1     서류 접수 ＞ Foundation Interview ＞ Tech · In-depth...
# 2     • 서류 전형 ＞ 1차 인터뷰 ＞ 2차 인터뷰 ＞ 처우 협의 ＞ 입사 확정\n• 상...
# 3     | 전형절차\n 서류전형 ＞ 직무 인터뷰 ＞ 컬쳐핏 인터뷰＞ 최종합격\n• 지원자의...
# 4     [제출 서류]\n• 경력기술서가 포함된 이력서는 필수 제출 사항입니다.\n     ...
# ...                                                 ...
# 9995                 • 서류전형 ＞ 1차면접 ＞ 2차면접 ＞ 임원면접 ＞ 최종합격
# 9996
# 9997                              서류 면접 - 대면 면접 - 결과 발표
# 9998                              서류 전형 - 대면 면접 - 결과 발표
# 9999                                     서류전형-1차면접-합격통보
#
#                                              attraction          company  \
# 0     [휴가비, 의료비지원, 건강검진지원, 편의시설, 자기계발지원, 수평적조직, 설립4~...  씨제이올리브영(CJ올리브영)
# 1     [건강검진지원, 유급휴가, 휴가비, 복지포인트, 장비지원, 식대지원, 설립4~9년,...       테크타카(ARGO)
# 2     [사내동호회, 휴가비, 식대지원, 커피·스낵바, 건강검진지원, 편의시설, 수평적조직...          여기어때컴퍼니
# 3     [커피·스낵바, 자유로운휴가, 휴가비, 식대지원, 50명이하, 설립4~9년, 보너스...       짐싸(ZIMSSA)
# 4     [유급휴가, 자기계발지원, 51~300명, 설립4~9년, 연봉상위6~10%, 인원 ...         케이티밀리의서재
# ...                                                 ...              ...
# 9995           [51~300명, 보너스, 장비지원, 설립10년이상, 연봉 업계평균이상]             오진상사
# 9996  [커피·스낵바, 식대지원, 단체보험, 스톡옵션, 유망산업, 누적투자100억이상, 유...     원티드_일본 현지 채용
# 9997                                    [50명이하, 설립3년이하]            울림더하기
# 9998                                    [50명이하, 설립3년이하]            울림더하기
# 9999                      [보너스, 50명이하, 인원 급성장, 설립10년이상]             이엔이텍
#
#      country location district category_parent                category_child  \
# 0         한국       서울      용산구             디자인                     [UX 디자이너]
# 1         한국       서울      서초구              개발  [자바 개발자, 서버 개발자, 소프트웨어 엔지니어]
# 2         한국       서울      강남구             디자인   [그래픽 디자이너, 웹 디자이너, UX 디자이너]
# 3         한국       서울      강남구         경영·비즈니스              [PM·PO, 서비스 기획자]
# 4         한국       서울      마포구             디자인  [그래픽 디자이너, 일러스트레이터, UX 디자이너]
# ...      ...      ...      ...             ...                           ...
# 9995      한국       서울     서대문구              영업            [외부영업, 기술영업, 기업영업]
# 9996      한국       서울     None         경영·비즈니스              [지역 관리 매니저, 지점장]
# 9997      한국       서울      서초구              금융                     [보험 에이전트]
# 9998      한국       서울      서초구              금융                     [보험 에이전트]
# 9999      한국       충남      당진시           제조·생산            [기계·설비·설계, 생산 관리자]
#
#                skill  annual_from  annual_to  is_newbie    due_time  job_id
# 0                 []            4         11      False        None  278301
# 1                 []            0          5       True        None  278604
# 2                 []            3          7      False        None  278837
# 3                 []            0          1       True  2025-05-31  278653
# 4                 []            5         10      False        None  280236
# ...              ...          ...        ...        ...         ...     ...
# 9995              []            2         10      False        None  238874
# 9996              []            5        100      False        None  228775
# 9997              []            0         10       True        None  223566
# 9998              []            0         10       True        None  235575
# 9999  [기계 설계, 기계 도면]            2          2      False        None  237274
#
# [10000 rows x 20 columns]

# %%
post_detail.to_json('../Data_Files/wanted_detail_20250515.txt',force_ascii=False)

# %%
post_improve_detail = toImproveDataFrame(post_detail)

# %%
split_columns = ['main_tasks','requirements','preferred_points','benefits','hire_rounds']

for column in split_columns:
    post_improve_detail[column] = post_improve_detail[column].apply(lambda x: x.split('\n') if isinstance(x, str) else x)

post_improve_detail.drop(columns=['country'],inplace=True)

# %%
post_improve_detail.drop_duplicates(subset=['position'],inplace=True)

# %%
post_improve_detail.set_index('job_id',inplace=True)

# %%
columns = post_improve_detail.columns
columns = columns.tolist()
for col in columns:
    post_improve_detail[col] = post_improve_detail[col].apply(lambda x: x.replace('\n','') if isinstance(x, str) else x)

# %%
post_improve_detail.rename(columns={
    'position' : '제목',
    'intro' : '회사 소개',
    'main_tasks':'주요 업무',
    'requirements':'자격 요건',
    'preferred_points':'우대 사항',
    'benefits':'복지',
    'hire_rounds':'채용절차',
    'attraction' : '장점',
    'company':'회사명',
    'location':'근무지',
    'district' : '지역',
    'category_parent' : '직군',
    'category_child' : '직무',
    'skill' : '기술 스택',
    'annual_from' : '요구 최소 경력',
    'annual_to' : '요구 최대 경력',
    'is_newbie' : '신입 지원 가능 여부',
    'due_time' : '마감일',
},inplace=True)

# %%
import numpy as np

# 공백·탭·개행 모두 제거한 뒤 '' 이면 상시 공고
post_improve_detail["마감일"] = np.where(
    post_improve_detail["마감일"].astype(str).str.strip() == "",
    "상시 공고",
    post_improve_detail["마감일"]
)

# %%
post_improve_detail

# %%
post_improve_detail.T.to_json('../Data_Files/wanted_detail_improve_20250515.txt',force_ascii=False)
