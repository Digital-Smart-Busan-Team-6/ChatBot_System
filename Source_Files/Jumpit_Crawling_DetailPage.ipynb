# %%
from Jumpit_Crawling_Functions import *

# %%
data = crawlingDetailPage()
# Out:
# Loading: 1page [00:00, 10.34page/s]
# Loading: 1page [00:00, 12.80page/s]
# Loading: 1page [00:00, 13.23page/s]
# Loading: 1page [00:00, 12.41page/s]
# Loading: 1page [00:00, 12.72page/s]
# Loading: 1page [00:00, 13.41page/s]
# Loading: 1page [00:00,  9.93page/s]
# Loading: 1page [00:00, 12.17page/s]
# Loading: 1page [00:00, 12.33page/s]
# Loading: 1page [00:00, 11.81page/s]
# Loading: 1page [00:00, 12.02page/s]
# Loading: 1page [00:00, 12.18page/s]
# Loading: 1page [00:00,  7.26page/s]
# Loading: 1page [00:00, 11.48page/s]
# Loading: 1page [00:00, 12.47page/s]
# Loading: 1page [00:00, 11.81page/s]
# Loading: 1page [00:00, 11.53page/s]
# Loading: 1page [00:00, 10.74page/s]
# Loading: 1page [00:00, 10.79page/s]
# Loading: 1page [00:00, 12.04page/s]
# Loading: 1page [00:00, 11.81page/s]
# Loading: 1page [00:00, 11.82page/s]
# Loading: 1page [00:00, 11.04page/s]
# Loading: 1page [00:00, 11.16page/s]
# Loading: 1page [00:00, 10.08page/s]
# Loading: 1page [00:00, 12.18page/s]
# ...

# %%
detailDataFrame = pd.DataFrame(data)
detailDataFrame.set_index('id', inplace=True)

# %%
detailDataFrame
# Out:
#                        title company  \
# id
# 49678      서버개발팀 모바일 개발자(경력)   사이버다임
# 48941           BE Engineer    이마고웍스
# 49281              신입 개발자 채용   하이퍼에픽
# 49577        머신러닝 엔지니어 - 시니어    심플랫폼
# 48390           임베디드 S/W 개발자    넥스트랩
# ...                      ...     ...
# 50649  백엔드 서버 개발자 [경력 7년 이상]    아이피샵
# 49627       SAP CO 모듈 담당자 채용  영원아웃도어
# 49729  통신장비 연구개발 채용 - 주임/대리급   혜성테크윈
# 50250    네트워크 엔지니어 경력(10년이상)    텐빌리언
# 50049         임베디드 개발자 신입 채용  에프엘이에스
#
#                                                    pride  \
# id
# 49678                    [🚆2호선 역세권 기업, #유연근무제, #도서구입비지원]
# 48941  [🚆3호선 역세권 기업, 💰시리즈B 투자유치, #반바지/슬리퍼 OK, #수평적조직,...
# 49281                         [🚆9호선 역세권 기업, 🏢코퍼스코리아 계열사]
# 49577                                                 []
# 48390                              [🚆2호선 역세권 기업, #유연근무제]
# ...                                                  ...
# 50649                        [🚆5호선 역세권 기업, #자유복장, #전공우대]
# ...

# %%
toJsonFile(detailDataFrame, 20250511, 'Detail')

# %%
detailDataFrame = pd.read_json('../Data_Files/Crawling_DataFile_DetailPage_json_20250511.txt')

# %%
detailDataFrame.head(5)
# Out:
#                    title company  \
# 49678  서버개발팀 모바일 개발자(경력)   사이버다임
# 48941       BE Engineer    이마고웍스
# 49281          신입 개발자 채용   하이퍼에픽
# 49577    머신러닝 엔지니어 - 시니어    심플랫폼
# 48390       임베디드 S/W 개발자    넥스트랩
#
#                                                    pride  \
# 49678                    [🚆2호선 역세권 기업, #유연근무제, #도서구입비지원]
# 48941  [🚆3호선 역세권 기업, 💰시리즈B 투자유치, #반바지/슬리퍼 OK, #수평적조직,...
# 49281                         [🚆9호선 역세권 기업, 🏢코퍼스코리아 계열사]
# 49577                                                 []
# 48390                              [🚆2호선 역세권 기업, #유연근무제]
#
#                                                techStack  \
# 49678  [Android Studio, Node.js, Webpack, Redux, Reac...
# 48941  [MongoDB, TypeScript, Rust, NoSql, AWS, NestJS...
# 49281  [Git, Kotlin, TypeScript, Spring Boot, Node.js...
# 49577  [AI/인공지능, Helm, Linux, Kubernetes, TensorFlow,...
# 48390            [Linux, C++, Embedded, Python, Network]
#
#                                                 mainWork  \
# ...
