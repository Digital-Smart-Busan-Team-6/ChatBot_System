# %%
from Jumpit_Crawling_Functions import *

# %%
data = crawlingDetailPage()
# Out:
# Loading: 0page [00:00, ?page/s]
# Loading: 1page [00:00,  4.59page/s]
# Loading: 1page [00:00,  6.41page/s]
# Loading: 1page [00:00,  6.27page/s]
# Loading: 1page [00:00,  7.41page/s]
# Loading: 1page [00:00,  7.21page/s]
# Loading: 1page [00:00,  7.05page/s]
# Loading: 1page [00:00,  6.99page/s]
# Loading: 1page [00:00,  6.41page/s]
# Loading: 1page [00:00,  6.09page/s]
# Loading: 1page [00:00,  6.80page/s]
# Loading: 1page [00:00,  7.08page/s]
# Loading: 1page [00:00,  5.47page/s]
# Loading: 1page [00:00,  5.95page/s]
# Loading: 1page [00:00,  6.85page/s]
# Loading: 1page [00:00,  6.27page/s]
# Loading: 1page [00:00,  6.51page/s]
# Loading: 1page [00:00,  6.09page/s]
# Loading: 1page [00:00,  6.38page/s]
# Loading: 1page [00:00,  5.75page/s]
# Loading: 1page [00:00,  6.16page/s]
# Loading: 1page [00:00,  6.20page/s]
# Loading: 1page [00:00,  6.06page/s]
# Loading: 1page [00:00,  5.88page/s]
# Loading: 1page [00:00,  5.53page/s]
# Loading: 1page [00:00,  6.12page/s]
# ...

# %%
detailDataFrame = pd.DataFrame(data)

# %%
detailDataFrame
# Out:
#                           title  company  \
# 0             서버개발팀 모바일 개발자(경력)    사이버다임
# 1                AI연구팀장 경력10년이상  아이스크림아트
# 2                  BE Engineer     이마고웍스
# 3                     신입 개발자 채용    하이퍼에픽
# 4            Solution Developer    이마고웍스
# ...                         ...      ...
# 1422  생성형 AI 기반 통합 문서비서 솔루션 CTO  한국통신데이터
# 1423            소프트웨어개발자 경력자 채용    라온솔루션
# 1424         앱 개발자 경력 채용 (6~9년)     텐빌리언
# 1425             하드웨어 및 펌웨어 개발자    한솔리드텍
# 1426           NPU 컴파일러 개발 엔지니어     아티크론
#
#                                                   pride  \
# 0                       [🚆2호선 역세권 기업, #유연근무제, #도서구입비지원]
# 1                                         [🚆2호선 역세권 기업]
# 2     [🚆3호선 역세권 기업, 💰시리즈B 투자유치, #반바지/슬리퍼 OK, #수평적조직,...
# 3                            [🚆9호선 역세권 기업, 🏢코퍼스코리아 계열사]
# 4     [🚆3호선 역세권 기업, 💰시리즈B 투자유치, #반바지/슬리퍼 OK, #수평적조직,...
# ...                                                 ...
# 1422                                                 []
# ...

# %%
toJsonFile(detailDataFrame, 20250510, 'Detail')

# %%
detailDataFrame = pd.read_json('../Data_Files/Crawling_DataFile_DetailPage_json_20250510.txt')

# %%
detailDataFrame.head(5)
# Out:
#                 title  company  \
# 0   서버개발팀 모바일 개발자(경력)    사이버다임
# 1      AI연구팀장 경력10년이상  아이스크림아트
# 2        BE Engineer     이마고웍스
# 3           신입 개발자 채용    하이퍼에픽
# 4  Solution Developer    이마고웍스
#
#                                                pride  \
# 0                    [🚆2호선 역세권 기업, #유연근무제, #도서구입비지원]
# 1                                      [🚆2호선 역세권 기업]
# 2  [🚆3호선 역세권 기업, 💰시리즈B 투자유치, #반바지/슬리퍼 OK, #수평적조직,...
# 3                         [🚆9호선 역세권 기업, 🏢코퍼스코리아 계열사]
# 4  [🚆3호선 역세권 기업, 💰시리즈B 투자유치, #반바지/슬리퍼 OK, #수평적조직,...
#
#                                            techStack  \
# 0  [Android Studio, Node.js, Webpack, Redux, Reac...
# 1  [AI/인공지능, MySQL, REST API, React, Flow, Node.j...
# 2  [MongoDB, TypeScript, Rust, NoSql, AWS, NestJS...
# 3  [Git, Kotlin, TypeScript, Spring Boot, Node.js...
# 4                          [Figma, Confluence, Jira]
#
#                                             mainWork  \
# 0  [• 자사 솔루션 모바일 개발, - Destiny ECM(데스티니 ECM)은 고객사...
# ...
