# %%
from Wanted_Crawling import *

# %%
posts = get_wanted_crawling()

# %%
import pandas as pd

df = pd.DataFrame(posts['data'])
df.columns

# %%
df.to_json('../Data_Files/wanted_crawling.json', force_ascii=False)

# %%
response = requests.get('https://static.wanted.co.kr/tags?tags=skill')
response

# %%
skill = get_tags_json("skill")

# %%
category = get_tags_json("category")
category

# %%
posts = pd.read_json('../Data_Files/wanted_crawling.json')

# %%
posts.user_oriented_tags

# %%
posts.columns

# %%
post_skill_tags = posts['skill_tags']

# %%
df_skill = pd.DataFrame(skill['skill'])

# %%
df_skill

# %%
posts.to_json(force_ascii=False)

# %%
post_skill_tags = post_skill_tags.to_list()

# %%
post_skill_tags

# %%
for i in range(len(post_skill_tags)):
    post_skill_tags[i] = [x['name'] for x in post_skill_tags[i]]

# %%
response = requests.get('https://www.wanted.co.kr/wd/278604')

# %%
response
